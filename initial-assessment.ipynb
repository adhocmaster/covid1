# %%
import numpy as np
import pandas as pd

# %%
src = './Santa_Clara_County_Close_Contact_Summary_Data.csv'

dfSummary = pd.read_csv(src)

# %%
df.head(5)
# Out:
#            geo  average_contacts  median_contacts  contact_devices  contacts  \
# 0  60855001001          9.283333                4               60       544
# 1  60855001001          1.146341                1              164        94
# 2  60855001001          5.500000                3               50       262
# 3  60855001001          1.310345                1               29        19
# 4  60855001001          7.488372                3               43       316
#
#   country  local_date grouping_method geo_type      filter
# 0     USA    20200101             cel      cbg       noisy
# 1     USA    20200101  event_location      cbg       noisy
# 2     USA    20200101             cel      cbg  noisy_fast
# 3     USA    20200101  event_location      cbg  noisy_fast
# 4     USA    20200101             cel      cbg  noisy_slow

# %%
dfDistance = pd.read_csv('./1175035_Santa_Clara_County_cel_cdl_distance_report.tsv', '\t')
dfDistanceSummary = pd.read_csv('./1175035_Santa_Clara_County_cel_cdl_distance_report_summary.tsv', '\t')

# %%
dfDistanceSummary.head()
# Out:
#              Location                             Bucket          Type  \
# 0  Santa Clara County            Total visitors with CEL  CEL Distance
# 1  Santa Clara County  Median distance traveled from CEL  CEL Distance
# 2  Santa Clara County    Lives within 1 mile of location  CEL Distance
# 3  Santa Clara County        Lives between 1 and 2 miles  CEL Distance
# 4  Santa Clara County        Lives between 2 and 3 miles  CEL Distance
#
#    Visitor Count Percentage
# 0   1.418829e+06        NaN
# 1   3.979191e+01        NaN
# 2   1.100000e+01      0.00%
# 3   5.600000e+01      0.00%
# 4   2.480000e+02      0.02%

# %%
dfDistanceSummary.tail()
# Out:
#                Location Bucket             Type  Visitor Count Percentage
# 217  Santa Clara County    ESP  Top CDL Country          952.0      0.08%
# 218  Santa Clara County    SGP  Top CDL Country          827.0      0.07%
# 219  Santa Clara County    HKG  Top CDL Country          727.0      0.06%
# 220  Santa Clara County    MYS  Top CDL Country          693.0      0.06%
# 221  Santa Clara County    NGA  Top CDL Country          677.0      0.06%

# %%
dfDistance.head()
# Out:
#          Polygon Name                          Hashed Device Id  \
# 0  Santa Clara County  124866122d9f56a699e8c546c72db387568e131b
# 1  Santa Clara County  e736babeb6ea08d450314dfb33ab353f9eff45c4
# 2  Santa Clara County  016a10512ee0b9c54eab6e5b80f40fa0a36c334c
# 3  Santa Clara County  e0c3a54ae8e0da6a983a03d28b8f4879297c0d2a
# 4  Santa Clara County  6b4f4bbbd264273c6e405b3b1481ffabb522501f
#
#    Common Evening Lat  Common Evening Long Common Evening Country  \
# 0           37.271336          -121.823794                    USA
# 1           36.189990          -119.317362                    USA
# 2           39.417042          -119.768268                    USA
# 3           33.762377          -118.021034                    USA
# 4           34.212245          -119.152234                    USA
#
#   Common Evening State Common Evening Zip Common Evening Census  \
# 0                   CA              95111          060855120171
# ...
