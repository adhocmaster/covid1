# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()

# %%
src = './data/Santa_Clara_County_Close_Contact_Summary_Data.csv'

dfSummary = pd.read_csv(src)

# %%
dfSummary.head(5)
# Out:
#            geo  average_contacts  median_contacts  contact_devices  contacts  \
# 0  60855001001          9.283333                4               60       544
# 1  60855001001          1.146341                1              164        94
# 2  60855001001          5.500000                3               50       262
# 3  60855001001          1.310345                1               29        19
# 4  60855001001          7.488372                3               43       316
#
#   country  local_date grouping_method geo_type      filter
# 0     USA    20200101             cel      cbg       noisy
# 1     USA    20200101  event_location      cbg       noisy
# 2     USA    20200101             cel      cbg  noisy_fast
# 3     USA    20200101  event_location      cbg  noisy_fast
# 4     USA    20200101             cel      cbg  noisy_slow

# %%
dfSummary.tail(5)
# Out:
#                 geo  average_contacts  median_contacts  contact_devices  \
# 1608442  6085513500          1.672727                1              110
# 1608443  6085513500         11.377049                3               61
# 1608444  6085513500          1.622307                1              789
# 1608445  6085513500         57.760870                8               92
# 1608446  6085513500          1.676056                1              852
#
#          contacts country  local_date grouping_method geo_type      filter
# 1608442        92     USA    20200531  event_location    tract  noisy_fast
# 1608443       693     USA    20200531             cel    tract  noisy_slow
# 1608444       640     USA    20200531  event_location    tract  noisy_slow
# 1608445      5298     USA    20200531             cel    tract        none
# 1608446       714     USA    20200531  event_location    tract        none

# %%
dfSummary.describe()
# Out:
#                 geo  average_contacts  median_contacts  contact_devices  \
# count  1.608447e+06      1.608447e+06     1.608447e+06     1.608447e+06
# mean   4.672744e+10      6.028148e+00     2.631386e+00     2.493457e+02
# std    2.396728e+10      9.141985e+00     3.325294e+00     2.501634e+03
# min    6.085000e+03      1.000000e+00     1.000000e+00     1.000000e+00
# 25%    6.085512e+09      1.531915e+00     1.000000e+00     3.700000e+01
# 50%    6.085504e+10      3.307692e+00     2.000000e+00     7.700000e+01
# 75%    6.085508e+10      6.645161e+00     3.000000e+00     1.800000e+02
# max    6.085514e+10      5.498100e+02     6.870000e+02     2.117450e+05
#
#            contacts    local_date
# count  1.608447e+06  1.608447e+06
# mean   1.474978e+03  2.020031e+07
# std    3.273010e+04  1.402910e+02
# min    1.000000e+00  2.020010e+07
# 25%    6.300000e+01  2.020020e+07
# 50%    2.230000e+02  2.020032e+07
# 75%    6.770000e+02  2.020042e+07
# max    6.668446e+06  2.020053e+07

# %%
dfSummary[dfSummary.average_contacts > 1000]
# Out:
# Empty DataFrame
# Columns: [geo, average_contacts, median_contacts, contact_devices, contacts, country, local_date, grouping_method, geo_type, filter]
# Index: []

# %%
dfDistance = pd.read_csv('./data/1175035_Santa_Clara_County_cel_cdl_distance_report.tsv', '\t')
dfDistanceSummary = pd.read_csv('./data/1175035_Santa_Clara_County_cel_cdl_distance_report_summary.tsv', '\t')

# %%
dfDistanceSummary.head()
# Out:
#              Location                             Bucket          Type  \
# 0  Santa Clara County            Total visitors with CEL  CEL Distance
# 1  Santa Clara County  Median distance traveled from CEL  CEL Distance
# 2  Santa Clara County    Lives within 1 mile of location  CEL Distance
# 3  Santa Clara County        Lives between 1 and 2 miles  CEL Distance
# 4  Santa Clara County        Lives between 2 and 3 miles  CEL Distance
#
#    Visitor Count Percentage
# 0   1.418829e+06        NaN
# 1   3.979191e+01        NaN
# 2   1.100000e+01      0.00%
# 3   5.600000e+01      0.00%
# 4   2.480000e+02      0.02%

# %%
dfDistanceSummary.tail()
# Out:
#                Location Bucket             Type  Visitor Count Percentage
# 217  Santa Clara County    ESP  Top CDL Country          952.0      0.08%
# 218  Santa Clara County    SGP  Top CDL Country          827.0      0.07%
# 219  Santa Clara County    HKG  Top CDL Country          727.0      0.06%
# 220  Santa Clara County    MYS  Top CDL Country          693.0      0.06%
# 221  Santa Clara County    NGA  Top CDL Country          677.0      0.06%

# %%
dfDistance.head()
# Out:
#          Polygon Name                          Hashed Device Id  \
# 0  Santa Clara County  124866122d9f56a699e8c546c72db387568e131b
# 1  Santa Clara County  e736babeb6ea08d450314dfb33ab353f9eff45c4
# 2  Santa Clara County  016a10512ee0b9c54eab6e5b80f40fa0a36c334c
# 3  Santa Clara County  e0c3a54ae8e0da6a983a03d28b8f4879297c0d2a
# 4  Santa Clara County  6b4f4bbbd264273c6e405b3b1481ffabb522501f
#
#    Common Evening Lat  Common Evening Long Common Evening Country  \
# 0           37.271336          -121.823794                    USA
# 1           36.189990          -119.317362                    USA
# 2           39.417042          -119.768268                    USA
# 3           33.762377          -118.021034                    USA
# 4           34.212245          -119.152234                    USA
#
#   Common Evening State Common Evening Zip Common Evening Census  \
# 0                   CA              95111          060855120171
# ...
