# %%
import dask.dataframe as dd
import pandas as pd
from datetime import datetime, timedelta
exec(open("./lib/splitter.py").read())
exec(open("./lib/distance.py").read())

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
date = datetime.strptime('2000-01-01', "%Y-%m-%d")
inputFile = './data/splitted/out_2019-12-19.csv'
df = pd.read_csv(inputFile)

# %%
addGridColumns(df)

# %%
df.head()
# Out:
#                   pid                                       hid        lat  \
# 0  Santa Clara County  8b36e7aa0781e013ba4f656aaac11c87c6d63816  36.909643
# 1  Santa Clara County  863934991c5d1389bd16132567a286148108f3d0  36.912950
# 2  Santa Clara County  863934991c5d1389bd16132567a286148108f3d0  36.912956
# 3  Santa Clara County  863934991c5d1389bd16132567a286148108f3d0  36.912956
# 4  Santa Clara County  e707a9304de98308883ecac832ea47917f395cd5  36.903164
#
#           lon          ts        td   dw                   tz  gridX  gridY  \
# 0 -121.559312  1576782347  11:05:47  Thu  America/Los_Angeles   3096   9407
# 1 -121.555730  1576771243  08:00:43  Thu  America/Los_Angeles   3130   9443
# 2 -121.555730  1576771243  08:00:43  Thu  America/Los_Angeles   3130   9443
# 3 -121.555730  1576742443  00:00:43  Thu  America/Los_Angeles   3130   9443
# 4 -121.560289  1576773332  08:35:32  Thu  America/Los_Angeles   3032   9397
#
#       gridId
# 0  309609407
# 1  313009443
# 2  313009443
# 3  313009443
# 4  303209397

# %%
df.describe()
# Out:
#                  lat            lon            ts          gridX  \
# count  625711.000000  625711.000000  6.257110e+05  625711.000000
# mean       37.188565    -121.831195  1.576777e+09    5885.649771
# std         0.051240       0.143664  1.576298e+04     512.401150
# min        36.897680    -122.135359  1.576742e+09    2977.000000
# 25%        37.146322    -121.969633  1.576766e+09    5463.000000
# 50%        37.209496    -121.856618  1.576778e+09    6095.000000
# 75%        37.231438    -121.661815  1.576790e+09    6314.000000
# max        37.265624    -121.555730  1.576800e+09    6656.000000
#
#               gridY        gridId
# count  625711.00000  6.257110e+05
# mean     6688.04442  5.885717e+08
# std      1436.63701  5.123889e+07
# min      3646.00000  2.977094e+08
# 25%      5304.00000  5.463084e+08
# 50%      6434.00000  6.095065e+08
# 75%      8382.00000  6.314055e+08
# max      9443.00000  6.656051e+08

# %%
fig_dims = (10, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.relplot(x="gridX", y="gridY", ax=ax, data=df);
